# %%
import pandas as pd
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord

# %%
sqanti_classification = pd.read_table('./jurkat_classification.txt')
sqanti_novel_genes = sqanti_classification[sqanti_classification['associated_gene'].str.startswith('novel')]

novel_gene_isoforms = set(sqanti_novel_genes['isoform'])

novel_gene_sequences = []
for record in SeqIO.parse('./jurkat_corrected.fasta', 'fasta'):
    if record.id in novel_gene_isoforms:
        novel_gene_sequences.append(record)

SeqIO.write(novel_gene_sequences, './jurkat.novel_gene_isoforms.fasta', 'fasta')
# Out:
# 13240

# %%
# RUN CPAT then continue
cpat_best_orfs = pd.read_table('./jurkat_novel_gene.ORF_prob.best.tsv')
best_orf_accs = set(cpat_best_orfs['ID'])
# %%
best_orf_fasta = []
for record in SeqIO.parse('./jurkat_novel_gene.ORF_seqs.fa', 'fasta'):
    if record.id in best_orf_accs:
        accession = record.id.split('_')[0]

        translated_id = f'nv|{accession}|fullname GN=NOVELGENE'
        translated_seq = record.seq.translate(stop_symbol='')
        translated_record = SeqRecord(translated_seq, id=translated_id, description='')

        best_orf_fasta.append(translated_record)

SeqIO.write(best_orf_fasta,'./jurkat.novel_gene.CPAT.best.fasta', 'fasta')
# Out:
# 13209

# %%
high_scoring = cpat_best_orfs[cpat_best_orfs['Coding_prob'] > 0.364]

novel_gene_peptides = pd.read_excel('./NovelGenePeptides.xlsx')

# %%
sqanti_novel_genes.groupby('structural_category').size()
# Out:
# structural_category
# antisense        1871
# genic_intron       21
# intergenic      11348
# dtype: int64

# %%
def get_higheset_cpat_score(protein_accession, cpat_scores):
    accs = protein_accession.split('|')
    cpat_score = 0.0
    for acc in accs:
        if acc in cpat_scores.keys():
            if cpat_scores[acc] > cpat_score:
                cpat_score = cpat_scores[acc]
    return cpat_score

def get_sqanti_category(protein_accession, sqanti_categories):
    acc_categories = set()
    accs = protein_accession.split('|')
    for acc in accs:
        if acc in sqanti_categories:
            acc_categories.add(sqanti_categories[acc])

    return '|'.join(acc_categories)



cpat_scores = pd.Series(cpat_best_orfs['Coding_prob'].values, index=cpat_best_orfs['seq_ID']).to_dict()

sqanti_categories = pd.Series(sqanti_novel_genes['structural_category'].values, index=sqanti_novel_genes['isoform']).to_dict()

novel_gene_peptides['Highest CPAT Score'] = novel_gene_peptides['Protein Accession'].apply(lambda acc: get_higheset_cpat_score(acc, cpat_scores))
novel_gene_peptides['SQANTI structural category'] = novel_gene_peptides['Protein Accession'].apply(lambda acc: get_sqanti_category(acc, sqanti_categories))

peps_high_cpat = novel_gene_peptides[novel_gene_peptides['Highest CPAT Score']>0.364]
isoforms_with_peps_high_cpat = list(peps_high_cpat['Protein Accession'].str.split('|'))
isoforms_with_peps_high_cpat = set().union(*isoforms_with_peps_high_cpat)

# %%
sqanti_novel_genes[sqanti_novel_genes['isoform'].isin(isoforms_with_peps_high_cpat)]
# Out:
#             isoform  chrom strand  length  exons structural_category  \
# 21744      PB.901.1   chr1      -    3883      1          intergenic
# 85270    PB.13014.5  chr17      -    2930      1          intergenic
# 96654   PB.13888.20  chr17      +    2629      2          intergenic
# 110890   PB.15039.1  chr19      -    2614      1           antisense
# 110891   PB.15039.2  chr19      -    1536      2           antisense
# 195978    PB.7033.1   chr8      -    1923      3           antisense
#
#                        associated_gene associated_transcript  ref_length  \
# 21744                    novelGene_483                 novel         NaN
# 85270                   novelGene_9431                 novel         NaN
# 96654                   novelGene_9827                 novel         NaN
# 110890  novelGene_ENSG00000105497.8_AS                 novel         NaN
# 110891  novelGene_ENSG00000105497.8_AS                 novel         NaN
# 195978  novelGene_ENSG00000176595.4_AS                 novel         NaN
#
#         ref_exons  ...  CDS_genomic_end  predicted_NMD  perc_A_downstream_TTS  \
# 21744         NaN  ...              NaN            NaN                   60.0
# 85270         NaN  ...              NaN            NaN                   95.0
# 96654         NaN  ...              NaN            NaN                   80.0
# 110890        NaN  ...              NaN            NaN                   80.0
# 110891        NaN  ...              NaN            NaN                   65.0
# 195978        NaN  ...              NaN            NaN                  100.0
#
#         seq_A_downstream_TTS dist_to_cage_peak  within_cage_peak  \
# 21744   AAAAACAAAAATTAGGAGGT               NaN               NaN
# 85270   AAAAAGAAAAAAAAAAAAAA               NaN               NaN
# 96654   AAAAATAAATAAATAAAAAT               NaN               NaN
# 110890  AAGAAAAAAAAAAAAAAGGT               NaN               NaN
# 110891  AAAAATACAAAAAATTAGCC               NaN               NaN
# 195978  AAAAAAAAAAAAAAAAAAAA               NaN               NaN
#
#        dist_to_polya_site  within_polya_site  polyA_motif polyA_dist
# 21744                 NaN                NaN          NaN        NaN
# 85270                 NaN                NaN          NaN        NaN
# 96654                 NaN                NaN          NaN        NaN
# 110890                NaN                NaN          NaN        NaN
# 110891                NaN                NaN          NaN        NaN
# 195978                NaN                NaN          NaN        NaN
#
# [6 rows x 45 columns]

# %%
novel_gene_peptides
# Out:
#                                   File Name  Scan Number  Scan Retention Time  \
# 0               120426_Jurkat_highLC_Frac17        10620             88.51345
# 1   120426_Jurkat_highLC_Frac8_120430121912         4652             46.01599
# 2               120426_Jurkat_highLC_Frac11        20333            148.36445
# 3               120426_Jurkat_highLC_Frac17         4589             53.38795
# 4                120426_Jurkat_highLC_Frac2         1910             29.95894
# 5                120426_Jurkat_highLC_Frac9         1834             27.62694
# 6               120426_Jurkat_highLC_Frac27        16997            162.04191
# 7               120426_Jurkat_highLC_Frac27        10561            108.58996
# 8               120426_Jurkat_highLC_Frac17         4369             52.11873
# 9                120426_Jurkat_highLC_Frac9         4012             46.18971
# 10               120426_Jurkat_highLC_Frac4         3250             42.53315
# 11               120426_Jurkat_highLC_Frac3         6025             59.67419
# 12              120426_Jurkat_highLC_Frac28        13780            157.40900
# 13              120426_Jurkat_highLC_Frac11         4450             48.80687
# 14               120426_Jurkat_highLC_Frac5         2210             30.64815
# 15              120426_Jurkat_highLC_Frac25         6477             75.42390
# 16               120426_Jurkat_highLC_Frac3         5990             59.46529
# 17              120426_Jurkat_highLC_Frac24         1727             28.38444
# 18              120426_Jurkat_highLC_Frac12        11341             90.84380
# 19              120426_Jurkat_highLC_Frac17         4665             53.83557
# 20               120426_Jurkat_highLC_Frac4         8429             74.30605
# 21              120426_Jurkat_highLC_Frac17         4360             52.07044
# 22              120426_Jurkat_highLC_Frac26        19197            167.67732
# 23               120426_Jurkat_highLC_Frac2         5331             58.81659
# 24              120426_Jurkat_highLC_Frac12         8109             71.73556
# 25  120426_Jurkat_highLC_Frac7_120430090151         3600             43.95352
# 26              120426_Jurkat_highLC_Frac17         3121             43.93568
# 27              120426_Jurkat_highLC_Frac16         6602             61.19798
# 28              120426_Jurkat_highLC_Frac23         4594             57.58046
# 29              120426_Jurkat_highLC_Frac25        11043            104.78458
# 30              120426_Jurkat_highLC_Frac11         4432             48.69773
# 31              120426_Jurkat_highLC_Frac11         3578             43.66515
# 32              120426_Jurkat_highLC_Frac17         6353             63.60533
# 33              120426_Jurkat_highLC_Frac13         3576             43.57893
# 34              120426_Jurkat_highLC_Frac12         3619             45.76173
#
#     Num Experimental Peaks  Total Ion Current  Precursor Scan Number  \
# 0                      200       2.007754e+06                  10617
# 1                      200       8.670441e+05                   4649
# 2                      169       1.105796e+06                  20330
# 3                      193       1.426055e+06                   4583
# 4                      200       9.156746e+05                   1904
# 5                      175       1.684308e+06                   1833
# 6                      200       1.562637e+05                  16994
# 7                      128       1.166158e+07                  10560
# 8                      175       4.884039e+06                   4366
# 9                      200       2.700783e+06                   4006
# 10                     178       1.392042e+06                   3249
# 11                     200       1.185980e+06                   6022
# 12                     200       1.017445e+05                  13778
# 13                     190       3.455390e+07                   4449
# 14                     177       1.772643e+06                   2206
# 15                     133       1.240443e+06                   6475
# 16                     152       5.785662e+06                   5987
# 17                     200       1.222645e+05                   1726
# 18                     176       2.606427e+06                  11339
# 19                      70       1.293612e+06                   4660
# 20                     111       5.716067e+05                   8425
# 21                      63       5.184224e+07                   4359
# 22                      49       3.103453e+05                  19191
# 23                     131       9.525690e+05                   5326
# 24                      88       1.243210e+06                   8105
# 25                     150       4.213645e+06                   3594
# 26                     138       3.353520e+05                   3115
# 27                     127       6.974130e+07                   6600
# 28                     195       2.164598e+06                   4592
# 29                     188       1.720968e+06                  11040
# 30                     153       3.470160e+06                   4428
# 31                     150       1.254571e+07                   3577
# 32                     135       3.791816e+06                   6347
# 33                      89       1.100607e+07                   3574
# 34                      94       1.552546e+07                   3618
#
#     Precursor Charge  Precursor MZ  Precursor Mass   Score  ...  \
# 0                  2     811.38343      1620.75230  18.266  ...
# 1                  2     875.92231      1749.83006  11.049  ...
# 2                  2     728.88694      1455.75933  10.289  ...
# 3                  1     717.44904       716.44176  10.103  ...
# 4                  2     409.20625       816.39794  10.093  ...
# 5                  2     468.25664       934.49872  10.068  ...
# 6                  2     790.90874      1579.80293  10.034  ...
# 7                  2     708.35335      1414.69215   9.225  ...
# 8                  2     398.21637       794.41819   9.204  ...
# 9                  2     494.77506       987.53557   9.164  ...
# 10                 2     451.23452       900.45450   9.161  ...
# 11                 2     648.30682      1294.59909   9.146  ...
# 12                 2     552.79803      1103.58152   9.129  ...
# 13                 2     490.75571       979.49686   9.128  ...
# 14                 2     433.22899       864.44342   9.127  ...
# 15                 2     472.78488       943.55521   9.113  ...
# 16                 2     532.24242      1062.47028   9.097  ...
# 17                 2     483.25982       964.50509   9.064  ...
# 18                 2    1059.07909      2116.14362   9.048  ...
# 19                 2     457.77286       913.53117   8.462  ...
# 20                 2     604.77417      1207.53379   8.305  ...
# 21                 2     390.21899       778.42343   8.273  ...
# 22                 2     489.80785       977.60115   8.253  ...
# 23                 2     381.19275       760.37095   8.242  ...
# 24                 2     539.30075      1076.58695   8.222  ...
# 25                 2     402.72490       803.43525   8.191  ...
# 26                 1     687.43777       686.43049   8.188  ...
# 27                 3     479.25115      1434.73163   8.184  ...
# 28                 3     372.87173      1115.59336   8.178  ...
# 29                 3     499.92136      1496.74224   8.173  ...
# 30                 2     447.22925       892.44394   8.169  ...
# 31                 2     371.21614       740.41773   8.168  ...
# 32                 2     482.28343       962.55231   8.168  ...
# 33                 2     343.71328       685.41201   8.162  ...
# 34                 2     322.21058       642.40660   8.159  ...
#
#     Cumulative Target  Cumulative Decoy    QValue Cumulative Target Notch  \
# 0               18067                 0  0.000000                   17977
# 1               57669                24  0.000414                   57273
# 2               59639                28  0.000469                   59226
# 3               63709                76  0.001192                   63267
# 4               63924                85  0.001329                   63476
# 5               64369                99  0.001537                   63903
# 6               64842               111  0.001710                   64335
# 7               67736               136  0.002006                   67220
# 8               68147               146  0.002142                   67624
# 9               69077               177  0.002562                   68545
# 10              69164               183  0.002645                   68630
# 11              69544               196  0.002818                   69004
# 12              69935               234  0.003346                   69388
# 13              69949               237  0.003388                   69402
# 14              70001               244  0.003485                   69453
# 15              70336               274  0.003895                   69780
# 16              70779               312  0.004408                   70213
# 17              71561               416  0.005813                   70962
# 18              71918               463  0.006438                   71293
# 19              72475               516  0.007111                   71800
# 20              73450               541  0.007361                   72774
# 21              73833               552  0.007475                   73154
# 22              74107               560  0.007552                   73428
# 23              74288               565  0.007602                   73608
# 24              74598               582  0.007802                   73915
# 25              75185               622  0.008269                   74501
# 26              75246               625  0.008299                   74562
# 27              75346               630  0.008361                   74659
# 28              75491               644  0.008527                   74803
# 29              75596               655  0.008664                   74907
# 30              75700               669  0.008838                   75011
# 31              75726               676  0.008927                   75037
# 32              75733               678  0.008952                   75044
# 33              75881               699  0.009212                   75191
# 34              75962               714  0.009399                   75265
#
#    Cumulative Decoy Notch  QValue Notch       PEP PEP_QValue  \
# 0                       0      0.000000  0.000187   0.000083
# 1                      21      0.000365  0.841718   0.045523
# 2                      25      0.000422  0.301155   0.009264
# 3                      72      0.001137  0.036388   0.001660
# 4                      81      0.001275  0.763988   0.034482
# 5                      92      0.001439  0.002824   0.000263
# 6                     102      0.001584  0.837348   0.044724
# 7                     126      0.001872  0.028647   0.001413
# 8                     136      0.002011  0.006238   0.000437
# 9                     166      0.002421  0.295279   0.009085
# 10                    172      0.002505  0.088234   0.003082
# 11                    184      0.002666  0.873151   0.051618
# 12                    218      0.003141  0.200765   0.006165
# 13                    221      0.003184  0.000135   0.000067
# 14                    227      0.003268  0.008066   0.000536
# 15                    251      0.003597  0.333060   0.010348
# 16                    279      0.003974  0.000876   0.000158
# 17                    362      0.005101  0.010341   0.000651
# 18                    394      0.005526  0.315853   0.009750
# 19                    430      0.005981  0.061046   0.002386
# 20                    453      0.006221  0.967076   0.100616
# 21                    464      0.006341  0.008012   0.000533
# 22                    472      0.006424  0.920594   0.066851
# 23                    477      0.006477  0.957363   0.089676
# 24                    492      0.006654  0.382077   0.012142
# 25                    528      0.007084  0.900218   0.059344
# 26                    531      0.007116  0.036544   0.001663
# 27                    536      0.007179  0.534436   0.018721
# 28                    547      0.007310  0.994701   0.212552
# 29                    558      0.007449  0.007449   0.000503
# 30                    571      0.007612  0.092203   0.003190
# 31                    577      0.007689  0.086961   0.003047
# 32                    579      0.007715  0.923610   0.068125
# 33                    598      0.007953  0.516271   0.017788
# 34                    611      0.008117  0.232553   0.007157
#
#    Highest CPAT Score  SQANTI structural category
# 0            0.999924                  intergenic
# 1            0.007278                   antisense
# 2            0.101972                  intergenic
# 3            0.017964                  intergenic
# 4            0.060343                  intergenic
# 5            0.993432                   antisense
# 6            0.820876                  intergenic
# 7            0.279100                  intergenic
# 8            0.021512                  intergenic
# 9            0.189291                  intergenic
# 10           0.154563                  intergenic
# 11           0.403403                  intergenic
# 12           0.180233                   antisense
# 13           0.314071                  intergenic
# 14           0.121575                  intergenic
# 15           0.042284                  intergenic
# 16           0.026011                  intergenic
# 17           0.025562                   antisense
# 18           0.937286                   antisense
# 19           0.154772                  intergenic
# 20           0.145507                  intergenic
# 21           0.021512                  intergenic
# 22           0.007602                  intergenic
# 23           0.238880                  intergenic
# 24           0.018615                  intergenic
# 25           0.013523                  intergenic
# 26           0.133319                  intergenic
# 27           0.076203                  intergenic
# 28           0.019129                  intergenic
# 29           0.067998                   antisense
# 30           0.079351                  intergenic
# 31           0.051292                  intergenic
# 32           0.035529                  intergenic
# 33           0.044045                  intergenic
# 34           0.022382                   antisense
#
# [35 rows x 57 columns]

# %%
novel_gene_peptides.columns
# Out:
# Index(['File Name', 'Scan Number', 'Scan Retention Time',
#        'Num Experimental Peaks', 'Total Ion Current', 'Precursor Scan Number',
#        'Precursor Charge', 'Precursor MZ', 'Precursor Mass', 'Score',
#        'Delta Score', 'Notch', 'Base Sequence', 'Full Sequence',
#        'Essential Sequence', 'PSM Count (unambiguous, <0.01 q-value)', 'Mods',
#        'Mods Chemical Formulas', 'Mods Combined Chemical Formula',
#        'Num Variable Mods', 'Missed Cleavages', 'Peptide Monoisotopic Mass',
#        'Mass Diff (Da)', 'Mass Diff (ppm)', 'Protein Accession',
#        'Protein Name', 'Gene Name', 'Organism Name',
#        'Identified Sequence Variations', 'Splice Sites', 'Contaminant',
#        'Decoy', 'Peptide Description', 'Start and End Residues In Protein',
#        'Previous Amino Acid', 'Next Amino Acid', 'Theoreticals Searched',
#        'Decoy/Contaminant/Target', 'Matched Ion Series',
#        'Matched Ion Mass-To-Charge Ratios', 'Matched Ion Mass Diff (Da)',
#        'Matched Ion Mass Diff (Ppm)', 'Matched Ion Intensities',
#        'Matched Ion Counts', 'Normalized Spectral Angle', 'Localized Scores',
#        'Improvement Possible', 'Cumulative Target', 'Cumulative Decoy',
#        'QValue', 'Cumulative Target Notch', 'Cumulative Decoy Notch',
#        'QValue Notch', 'PEP', 'PEP_QValue', 'Highest CPAT Score',
#        'SQANTI structural category'],
#       dtype='object')

# %%
novel_gene_peptides.to_csv('./novel_gene_peptides.tsv', sep='\t', index=False)
